# %% [markdown]
# <a href="https://colab.research.google.com/github/Lohith-LM/python-learning-journey/blob/main/07_user_input_and_type_casting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Taking string input from the user
name = input("Enter your name: ")

# Taking numeric input and converting it to integer
age = int(input("Enter your age: "))

# Displaying formatted output
print("Hello " + name + "!")
print("You are " + str(age) + " years old.")

# Performing arithmetic using user input
next_year_age = age + 1
print("Next year, you will be " + str(next_year_age) + ".")
# Out:
# Enter your name: LOHITH L M
# Enter your age: 20
# Hello LOHITH L M!
# You are 20 years old.
# Next year, you will be 21.
