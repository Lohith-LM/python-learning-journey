# %% [markdown]
# <a href="https://colab.research.google.com/github/Lohith-LM/python-learning-journey/blob/main/PRINT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world")   #whatever is inside the " " will be printed as output as it is
# Out:
# Hello world

# %%
print("   /|")
print("  / |")         #this is how u can print a shape
print(" /  |")
print("/___|")
# Out:
#    /|
#   / |
#  /  |
# /___|
